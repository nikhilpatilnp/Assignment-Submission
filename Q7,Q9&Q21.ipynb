# %% [markdown]
# Question no 7

# %%
import pandas as pd
import numpy as np
import statistics


data = pd.read_csv("/content/Q7 (1).csv")

# %%
print(data)
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
data.mean()
# Out:
# <ipython-input-6-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
data.median()
# Out:
# <ipython-input-7-135339ac59ce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
data.mode().dropna()
# Out:
#     Unnamed: 0  Points  Score  Weigh
# 0  AMC Javelin    3.07   3.44  17.02

# %%
print("Variance:")
print("Points:", calculate_variance(points))
print("Score:", calculate_variance(score))
print("Weigh:", calculate_variance(weigh))
print()
# Out:
# Variance:
# Points: 0.27694755859375
# Score: 0.927460875
# Weigh: 3.0933796874999997

# %%
print("Standard Deviation:")
print("Points:", calculate_std_dev(points))
print("Score:", calculate_std_dev(score))
print("Weigh:", calculate_std_dev(weigh))
print()
# Out:
# Standard Deviation:
# Points: 0.526258072236189
# Score: 0.9630477013107918
# Weigh: 1.758800638929836

# %%
print("Range:")
print("Points:", calculate_range(points))
print("Score:", calculate_range(score))
print("Weigh:", calculate_range(weigh))
# Out:
# Range:
# Points: 2.17
# Score: 3.9110000000000005
# Weigh: 8.399999999999999

# %% [markdown]
# Question NO 9 A

# %%
data = pd.read_csv("/content/Q9_a (1).csv")
data
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
import numpy as np
from scipy.stats import*
skewness = data.skew()
print("Skewness:", skewness)
# Out:
# Skewness: Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
kurtosis = data.kurtosis()
print("Kurtosis:", kurtosis)
# Out:
# Kurtosis: Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(data['speed'], data['dist'])
plt.xlabel('Speed')
plt.ylabel('Distance')
plt.title('Scatter Plot of Speed vs Distance')
plt.show()

# %% [markdown]
# Question NO 9 B

# %%
data = pd.read_csv("/content/Q9_b (1).csv")
data
# Out:
#     Unnamed: 0          SP         WT
# 0            1  104.185353  28.762059
# 1            2  105.461264  30.466833
# 2            3  105.461264  30.193597
# 3            4  113.461264  30.632114
# 4            5  104.461264  29.889149
# ..         ...         ...        ...
# 76          77  169.598513  16.132947
# 77          78  150.576579  37.923113
# 78          79  151.598513  15.769625
# 79          80  167.944460  39.423099
# 80          81  139.840817  34.948615
#
# [81 rows x 3 columns]

# %%
skewness = data.skew()
print("Skewness:", skewness)
# Out:
# Skewness: Unnamed: 0    0.000000
# SP            1.611450
# WT           -0.614753
# dtype: float64

# %%
kurtosis = data.kurtosis()
print("Kurtosis:", kurtosis)
# Out:
# Kurtosis: Unnamed: 0   -1.200000
# SP            2.977329
# WT            0.950291
# dtype: float64

# %%
plt.scatter(data['SP'], data['WT'])
plt.xlabel('SP')
plt.ylabel('WT')
plt.title('Scatter Plot of SP vs WT')
plt.show()

# %% [markdown]
# Question NO 21

# %%
data = pd.read_csv("/content/Cars (1).csv")
data
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
data['MPG']
# Out:
# 0     53.700681
# 1     50.013401
# 2     50.013401
# 3     45.696322
# 4     50.504232
#         ...
# 76    36.900000
# 77    19.197888
# 78    34.000000
# 79    19.833733
# 80    12.101263
# Name: MPG, Length: 81, dtype: float64

# %%
plt.hist('MPG')
plt.xlabel('MPG')
plt.ylabel('Frequency')
plt.title('Histogram of MPG')
plt.show()

# %%
data = pd.read_csv("/content/wc-at.csv")
data
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.hist(data, bins='auto', edgecolor='black')
plt.xlabel('AT')
plt.ylabel('Frequency')
plt.title('Histogram of Adipose Tissue (AT)')

plt.subplot(1, 2, 2)
plt.hist(data, bins='auto', edgecolor='black')
plt.xlabel('Waist')
plt.ylabel('Frequency')
plt.title('Histogram of Waist Circumference')
# Out:
# Text(0.5, 1.0, 'Histogram of Waist Circumference')
